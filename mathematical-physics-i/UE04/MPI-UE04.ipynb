# %%
pretty_print_default(True)
var('x, alpha')
F(x) = (x+alpha)^2*(x^2-alpha)
F
# Out:
# x |--> (x^2 - alpha)*(alpha + x)^2

# %%
A = (alpha == 1.)
plot(F.subs(A), (x,-2,1.5))
# Out:
# Graphics object consisting of 1 graphics primitive
