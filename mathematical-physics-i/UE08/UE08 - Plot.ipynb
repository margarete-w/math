# %%
pretty_print_default(true)
var('x_1')
f(x_1) = x_1^4-.5*x_1^3
f
# Out:
# x_1 |--> x_1^4 - 0.500000000000000*x_1^3

# %%
plot(f, (-0.2,0.6))
# Out:
# Graphics object consisting of 1 graphics primitive
